# %% [markdown]
# # Exploratory Data analysis Trajectory
#
#
# #### 1. import libaries

# %%
# relevant libs
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import geopandas as gpd
import movingpandas as mpd
import datetime

# %% [markdown]
# #### 2. Import Data

# %%
# read in the data
traj_gdf = gpd.read_file('../scratch/traj.geojson')
picks_gdf = gpd.read_file('../scratch/picks.geojson')

# %% [markdown]
# #### 3. Data Wrangling

# %%
def create_Trajectory_object(traj_gdf):

    trajectory = mpd.Trajectory(traj_gdf, traj_id='traj_id', t='t')
    trajectory.add_acceleration()
    trajectory.add_speed()
    trajectory.add_timedelta()

    return trajectory

trajectory = create_Trajectory_object(traj_gdf)

# %%
def change_date_time(gdf, col_name, time_change):
    picks_gdf[col_name] = picks_gdf[col_name] + pd.to_timedelta(time_change)
    return gdf

picks_gdf = change_date_time(picks_gdf, 'date_taken', '2 hours')

# %% [markdown]
# #### 4. Explore data

# %%
print('Trajectory start time: ', traj_gdf['t'].min())
print('Trajectory end time: ', traj_gdf['t'].max())
print('Picks start time: ', picks_gdf['date_taken'].min())
print('Picks end time: ', picks_gdf['date_taken'].max())
# Out:
# Trajectory start time:  2023-08-19 10:08:43
# Trajectory end time:  2023-08-19 16:22:21
# Picks start time:  2023-08-19 14:12:31
# Picks end time:  2023-08-19 20:19:32

# %%
traj_gdf.head()
# Out:
#                     t  track_id  traj_id                  geometry
# 0 2023-08-19 10:08:43         1        1  POINT (4.73950 52.64884)
# 1 2023-08-19 10:08:44         1        1  POINT (4.73953 52.64880)
# 2 2023-08-19 10:08:45         1        1  POINT (4.73953 52.64879)
# 3 2023-08-19 10:08:46         1        1  POINT (4.73954 52.64880)
# 4 2023-08-19 10:08:47         1        1  POINT (4.73955 52.64881)

# %%
picks_gdf.head()
# Out:
#        id  verification     phone          date_taken       date_uploaded  \
# 0  452620             2  iPhone 6 2023-08-19 14:41:09 2023-08-20 10:55:39
# 1  452621             2  iPhone 6 2023-08-19 14:49:32 2023-08-20 10:56:05
# 2  452622             2  iPhone 6 2023-08-19 18:13:51 2023-08-20 10:56:08
# 3  452623             2  iPhone 6 2023-08-19 15:18:32 2023-08-20 10:56:12
# 4  452624             2  iPhone 6 2023-08-19 14:39:35 2023-08-20 10:56:16
#
#          lat       lon picked up  \
# 0  52.632703  4.751589       Yes
# 1  52.629392  4.751481       Yes
# 2  52.543922  4.720822       Yes
# 3  52.618136  4.757294       Yes
# 4  52.633186  4.750136       Yes
#
#                                              address  total_litter  ...  \
# 0  15A, Kanaalkade, Binnenstad-Oost, Alkmaar, Nor...           2.0  ...
# 1  87, Verdronkenoord, Binnenstad-Oost, Alkmaar, ...           2.0  ...
# 2  Geesterweg, Klein Dorregeest, Akersloot, Uitge...           2.0  ...
# 3  302D, Koelmalaan, Overdie, Alkmaar, North Holl...           2.0  ...
# 4  21A, Kanaalkade, Centrum, Alkmaar, North Holla...           4.0  ...
#
#   elec_small  elec_large batteries  balloons.1 life_buoy  other  \
# 0       None        None      None        None      None   None
# 1       None        None      None        None      None   None
# 2       None        None      None        None      None   None
# 3       None        None      None        None      None   None
# 4       None        None      None        None      None   None
#
#        custom_tag_1    custom_tag_2  custom_tag_3                  geometry
# 0  brand:desperados  certificate-76          None  POINT (4.75159 52.63270)
# 1       brand:amigo  certificate-76          None  POINT (4.75148 52.62939)
# 2      brand:shiraz  certificate-76          None  POINT (4.72082 52.54392)
# 3    certificate-76            None          None  POINT (4.75729 52.61814)
# 4    certificate-76            None          None  POINT (4.75014 52.63319)
#
# [5 rows x 293 columns]

# %% [markdown]
# #### 5. Data Visualization

# %%
trajectory.hvplot(title='Trajectory', line_width=7.0, tiles='OSM', frame_width=700, frame_height=500)
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='p1002'>
#   <div id="c3d26bda-c63c-4144-bf9a-97a8d36668af" data-root-id="p1002" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"f4e79cfb-9588-4db2-ae9c-30721a655265":{"version":"3.4.1","title":"Bokeh Application","roots":[{"type":"object","name":"panel.models.browser.BrowserInfo","id":"p1002"},{"type":"object","name":"panel.models.comm_manager.CommManager","id":"p1003","attributes":{"plot_id":"p1002","comm_id":"b9f944c037b24ddda525182fca4c8a14","client_comm_id":"535a5a9c830a4e8e9fceec6168b7790c"}}],"defs":[{"type":"model","name":"ReactiveHTML1"},{"type":"model","name":"FlexBox1","properties":[{"name":"align_content","kind":"Any","default":"flex-start"},{"name":"align_items","kind":"Any","default":"flex-start"},{"name":"flex_direction","kind":"Any","default":"row"},{"name":"flex_wrap","kind":"Any","default":"wrap"},{"name":"gap","kind":"Any","default":""},{"name":"justify_content","kind":"Any","default":"flex-start"}]},{"type":"model","name":"FloatPanel1","properties":[{"name":"config","kind":"Any","default":{"type":"map"}},{"name":"contained","kind":"Any","default":true},{"name":"position","kind":"Any","default":"right-top"},{"name":"offsetx","kind":"Any","default":null},{"name":"offsety","kind":"Any","default":null},{"name":"theme","kind":"Any","default":"primary"},{"name":"status","kind":"Any","default":"normalized"}]},{"type":"model","name":"GridStack1","properties":[{"name":"mode","kind":"Any","default":"warn"},{"name":"ncols","kind":"Any","default":null},{"name":"nrows","kind":"Any","default":null},{"name":"allow_resize","kind":"Any","default":true},{"name":"allow_drag","kind":"Any","default":true},{"name":"state","kind":"Any","default":[]}]},{"type":"model","name":"drag1","properties":[{"name":"slider_width","kind":"Any","default":5},{"name":"slider_color","kind":"Any","default":"black"},{"name":"value","kind":"Any","default":50}]},{"type":"model","name":"click1","properties":[{"name":"terminal_output","kind":"Any","default":""},{"name":"debug_name","kind":"Any","default":""},{"name":"clears","kind":"Any","default":0}]},{"type":"model","name":"FastWrapper1","properties":[{"name":"object","kind":"Any","default":null},{"name":"style","kind":"Any","default":null}]},{"type":"model","name":"NotificationAreaBase1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0}]},{"type":"model","name":"NotificationArea1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"notifications","kind":"Any","default":[]},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0},{"name":"types","kind":"Any","default":[{"type":"map","entries":[["type","warning"],["background","#ffc107"],["icon",{"type":"map","entries":[["className","fas fa-exclamation-triangle"],["tagName","i"],["color","white"]]}]]},{"type":"map","entries":[["type","info"],["background","#007bff"],["icon",{"type":"map","entries":[["className","fas fa-info-circle"],["tagName","i"],["color","white"]]}]]}]}]},{"type":"model","name":"Notification","properties":[{"name":"background","kind":"Any","default":null},{"name":"duration","kind":"Any","default":3000},{"name":"icon","kind":"Any","default":null},{"name":"message","kind":"Any","default":""},{"name":"notification_type","kind":"Any","default":null},{"name":"_destroyed","kind":"Any","default":false}]},{"type":"model","name":"TemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"BootstrapTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"TemplateEditor1","properties":[{"name":"layout","kind":"Any","default":[]}]},{"type":"model","name":"MaterialTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"copy_to_clipboard1","properties":[{"name":"fill","kind":"A ...
#   var render_items = [{"docid":"f4e79cfb-9588-4db2-ae9c-30721a655265","roots":{"p1002":"c3d26bda-c63c-4144-bf9a-97a8d36668af"},"root_ids":["p1002"]}];
#   var docs = Object.values(docs_json)
#   if (!docs) {
#     return
#   }
#   const py_version = docs[0].version.replace('rc', '-rc.').replace('.dev', '-dev.')
#   function embed_document(root) {
#     var Bokeh = get_bokeh(root)
#     Bokeh.embed.embed_items_notebook(docs_json, render_items);
#     for (const render_item of render_items) {
#       for (const root_id of render_item.root_ids) {
# 	const id_el = document.getElementById(root_id)
# 	if (id_el.children.length && (id_el.children[0].className === 'bk-root')) {
# 	  const root_el = id_el.children[0]
# 	  root_el.id = root_el.id + '-rendered'
# 	}
#       }
#     }
#   }
#   function get_bokeh(root) {
#     if (root.Bokeh === undefined) {
#       return null
#     } else if (root.Bokeh.version !== py_version) {
#       if (root.Bokeh.versions === undefined || !root.Bokeh.versions.has(py_version)) {
# 	return null
#       }
#       return root.Bokeh.versions.get(py_version);
#     } else if (root.Bokeh.version === py_version) {
#       return root.Bokeh
#     }
#     return null
#   }
#   function is_loaded(root) {
#     var Bokeh = get_bokeh(root)
#     return (Bokeh != null && Bokeh.Panel !== undefined)
#   }
#   if (is_loaded(root)) {
#     embed_document(root);
#   } else {
#     var attempts = 0;
#     var timer = setInterval(function(root) {
#       if (is_loaded(root)) {
#         clearInterval(timer);
#         embed_document(root);
#       } else if (document.readyState == "complete") {
#         attempts++;
#         if (attempts > 200) {
#           clearInterval(timer);
# 	  var Bokeh = get_bokeh(root)
# 	  if (Bokeh == null || Bokeh.Panel == null) {
#             console.warn("Panel: ERROR: Unable to run Panel code because Bokeh or Panel library is missing");
# 	  } else {
# 	    console.warn("Panel: WARNING: Attempting to render but not all required libraries could be resolved.")
# 	    embed_document(root)
# 	  }
#         }
#       }
#     }, 25, root)
#   }
# })(window);</script>
# :Overlay
#    .WMTS.I   :WMTS   [Longitude,Latitude]
#    .Path.I   :Path   [Longitude,Latitude]
#    .Points.I :Points   [Longitude,Latitude]   (triangle_angle)

# %%
def plot_traj_speed(trajectory, end_time=1):
    
    # Get the start time of the trajectory
    start_time = trajectory.get_start_time()

    # Calculate the end time for the subset (e.g., 2 hours after the start)
    end_time = start_time + datetime.timedelta(hours=1)

    # Create a subset of the trajectory
    subset = trajectory.get_segment_between(start_time, end_time)

    # Plot the subset
    return subset.hvplot(c='speed', line_width=7.0, tiles='OSM', frame_width=700, frame_height=500)


plot_traj_speed(trajectory, 1)
# Out:
# :Overlay
#    .WMTS.I   :WMTS   [Longitude,Latitude]
#    .Path.I   :Path   [Longitude,Latitude]   (speed)
#    .Points.I :Points   [Longitude,Latitude]   (speed,triangle_angle)

# %%
detector = mpd.TrajectoryStopDetector(trajectory)
stops = detector.get_stop_segments(min_duration= datetime.timedelta(seconds=15),max_diameter=10)

# %%
stops.hvplot(title='Stops', line_width=7.0, tiles='OSM', frame_width=700, frame_height=500) + picks_gdf.hvplot(geo=True, title='Picks', tiles="OSM", color='red', size=10, frame_width=700, frame_height=500) + trajectory.hvplot(title='Trajectory', line_width=7.0, tiles='OSM', frame_width=700, frame_height=500)
# Out:
# :Layout
#    .Overlay.I   :Overlay
#       .WMTS.I           :WMTS   [Longitude,Latitude]
#       .Path.I           :Path   [Longitude,Latitude]
#       .Path.II          :Path   [Longitude,Latitude]
#       .Path.III         :Path   [Longitude,Latitude]
#       .Path.IV          :Path   [Longitude,Latitude]
#       .Path.V           :Path   [Longitude,Latitude]
#       .Path.VI          :Path   [Longitude,Latitude]
#       .Path.VII         :Path   [Longitude,Latitude]
#       .Path.VIII        :Path   [Longitude,Latitude]
#       .Path.IX          :Path   [Longitude,Latitude]
#       .Path.X           :Path   [Longitude,Latitude]
#       .Path.XI          :Path   [Longitude,Latitude]
#       .Path.XII         :Path   [Longitude,Latitude]
#       .Path.XIII        :Path   [Longitude,Latitude]
#       .Path.XIV         :Path   [Longitude,Latitude]
#       .Path.XV          :Path   [Longitude,Latitude]
#       .Path.XVI         :Path   [Longitude,Latitude]
#       .Path.XVII        :Path   [Longitude,Latitude]
#       .Path.XVIII       :Path   [Longitude,Latitude]
#       .Path.XIX         :Path   [Longitude,Latitude]
#       .Path.XX          :Path   [Longitude,Latitude]
#       .Path.XXI         :Path   [Longitude,Latitude]
#       .Path.XXII        :Path   [Longitude,Latitude]
#       .Path.XXIII       :Path   [Longitude,Latitude]
#       .Path.XXIV        :Path   [Longitude,Latitude]
#       .Path.XXV         :Path   [Longitude,Latitude]
#       .Path.XXVI        :Path   [Longitude,Latitude]
#       .Path.XXVII       :Path   [Longitude,Latitude]
#       .Path.XXVIII      :Path   [Longitude,Latitude]
#       .Path.XXIX        :Path   [Longitude,Latitude]
#       .Path.XXX         :Path   [Longitude,Latitude]
#       .Path.XXXI        :Path   [Longitude,Latitude]
#       .Path.XXXII       :Path   [Longitude,Latitude]
#       .Path.XXXIII      :Path   [Longitude,Latitude]
#       .Path.XXXIV       :Path   [Longitude,Latitude]
#       .Path.XXXV        :Path   [Longitude,Latitude]
#       .Path.XXXVI       :Path   [Longitude,Latitude]
#       .Path.XXXVII      :Path   [Longitude,Latitude]
#       .Path.XXXVIII     :Path   [Longitude,Latitude]
#       .Path.XXXIX       :Path   [Longitude,Latitude]
#       .Path.XL          :Path   [Longitude,Latitude]
#       .Path.XLI         :Path   [Longitude,Latitude]
#       .Path.XLII        :Path   [Longitude,Latitude]
#       .Path.XLIII       :Path   [Longitude,Latitude]
#       .Path.XLIV        :Path   [Longitude,Latitude]
#       .Path.XLV         :Path   [Longitude,Latitude]
#       .Path.XLVI        :Path   [Longitude,Latitude]
#       .Path.XLVII       :Path   [Longitude,Latitude]
#       .Path.XLVIII      :Path   [Longitude,Latitude]
#       .Path.XLIX        :Path   [Longitude,Latitude]
#       .Path.L           :Path   [Longitude,Latitude]
#       .Path.LI          :Path   [Longitude,Latitude]
#       .Path.LII         :Path   [Longitude,Latitude]
#       .Path.LIII        :Path   [Longitude,Latitude]
#       .Path.LIV         :Path   [Longitude,Latitude]
#       .Path.LV          :Path   [Longitude,Latitude]
#       .Path.LVI         :Path   [Longitude,Latitude]
#       .Path.LVII        :Path   [Longitude,Latitude]
#       .Path.LVIII       :Path   [Longitude,Latitude]
#       .Path.LIX         :Path   [Longitude,Latitude]
#       .Path.LX          :Path   [Longitude,Latitude]
#       .Path.LXI         :Path   [Longitude,Latitude]
#       .Path.LXII        :Path   [Longitude,Latitude]
#       .Path.LXIII       :Path   [Longitude,Latitude]
#       .Path.LXIV        :Path   [Longitude,Latitude]
#       .Path.LXV         :Path   [Longitude,Latitude]
#       .Path.LXVI        :Path   [Longitude,Latitude]
#       .Path.LXVII       :Path   [Longitude,Latitude]
#       .Path.LXVIII      :Path   [Longitude,Latitude]
#       .Path.LXIX        :Path   [Longitude,Latitude]
#       .Path.LXX         :Path   [Longitude,Latitude]
#       .Path.LXXI        :Path   [Longitude,Latitude]
#       .Path.LXXII       :Path   [Longitude,Latitude]
#       .Path.LXXIII      :Path   [Longitude,Latitude]
#       .Path.LXXIV       :Path   [Longitude,Latitude]
#       .Path.LXXV        :Path   [Longitude,Latitude]
#       .Path.LXXVI       :Path   [Longitude,Latitude]
#       .Path.LXXVII      :Path   [Longitude,Latitude]
#       .Path.LXXVIII     :Path   [Longitude,Latitude]
#       .Path.LXXIX       :Path   [Longitude,Latitude]
#       .Path.LXXX        :Path   [Longitude,Latitude]
#       .Path.LXXXI       :Path   [Longitude,Latitude]
#       .Path.LXXXII      :Path   [Longitude,Latitude]
#       .Path.LXXXIII     :Path   [Longitude,Latitude]
#       .Path.LXXXIV      :Path   [Longitude,Latitude]
#       .Path.LXXXV       :Path   [Longitude,Latitude]
#       .Path.LXXXVI      :Path   [Longitude,Latitude]
#       .Path.LXXXVII     :Path   [Longitude,Latitude]
#       .Path.LXXXVIII    :Path   [Longitude,Latitude]
#       .Path.LXXXIX      :Path   [Longitude,Latitude]
#       .Path.XC          :Path   [Longitude,Latitude]
#       .Path.XCI         :Path   [Longitude,Latitude]
#       .Path.XCII        :Path   [Longitude,Latitude]
#       .Path.XCIII       :Path   [Longitude,Latitude]
#       .Path.XCIV        :Path   [Longitude,Latitude]
#       .Path.XCV         :Path   [Longitude,Latitude]
#       .Path.XCVI        :Path   [Longitude,Latitude]
#       .Path.XCVII       :Path   [Longitude,Latitude]
#       .Path.XCVIII      :Path   [Longitude,Latitude]
#       .Path.XCIX        :Path   [Longitude,Latitude]
#       .Path.C           :Path   [Longitude,Latitude]
#       .Path.CI          :Path   [Longitude,Latitude]
#       .Path.CII         :Path   [Longitude,Latitude]
#       .Path.CIII        :Path   [Longitude,Latitude]
#       .Path.CIV         :Path   [Longitude,Latitude]
#       .Path.CV          :Path   [Longitude,Latitude]
#       .Path.CVI         :Path   [Longitude,Latitude]
#       .Path.CVII        :Path   [Longitude,Latitude]
#       .Path.CVIII       :Path   [Longitude,Latitude]
#       .Path.CIX         :Path   [Longitude,Latitude]
#       .Path.CX          :Path   [Longitude,Latitude]
#       .Path.CXI         :Path   [Longitude,Latitude]
#       .Path.CXII        :Path   [Longitude,Latitude]
#       .Path.CXIII       :Path   [Longitude,Latitude]
#       .Path.CXIV        :Path   [Longitude,Latitude]
#       .Path.CXV         :Path   [Longitude,Latitude]
#       .Path.CXVI        :Path   [Longitude,Latitude]
#       .Path.CXVII       :Path   [Longitude,Latitude]
#       .Path.CXVIII      :Path   [Longitude,Latitude]
#       .Path.CXIX        :Path   [Longitude,Latitude]
#       .Path.CXX         :Path   [Longitude,Latitude]
#       .Path.CXXI        :Path   [Longitude,Latitude]
#       .Path.CXXII       :Path   [Longitude,Latitude]
#       .Path.CXXIII      :Path   [Longitude,Latitude]
#       .Path.CXXIV       :Path   [Longitude,Latitude]
#       .Path.CXXV        :Path   [Longitude,Latitude]
#       .Path.CXXVI       :Path   [Longitude,Latitude]
#       .Path.CXXVII      :Path   [Longitude,Latitude]
#       .Path.CXXVIII     :Path   [Longitude,Latitude]
#       .Path.CXXIX       :Path   [Longitude,Latitude]
#       .Path.CXXX        :Path   [Longitude,Latitude]
#       .Path.CXXXI       :Path   [Longitude,Latitude]
#       .Path.CXXXII      :Path   [Longitude,Latitude]
#       .Path.CXXXIII     :Path   [Longitude,Latitude]
#       .Path.CXXXIV      :Path   [Longitude,Latitude]
#       .Path.CXXXV       :Path   [Longitude,Latitude]
#       .Path.CXXXVI      :Path   [Longitude,Latitude]
#       .Path.CXXXVII     :Path   [Longitude,Latitude]
#       .Path.CXXXVIII    :Path   [Longitude,Latitude]
#       .Path.CXXXIX      :Path   [Longitude,Latitude]
#       .Path.CXL         :Path   [Longitude,Latitude]
#       .Path.CXLI        :Path   [Longitude,Latitude]
#       .Path.CXLII       :Path   [Longitude,Latitude]
#       .Path.CXLIII      :Path   [Longitude,Latitude]
#       .Path.CXLIV       :Path   [Longitude,Latitude]
#       .Path.CXLV        :Path   [Longitude,Latitude]
#       .Path.CXLVI       :Path   [Longitude,Latitude]
#       .Path.CXLVII      :Path   [Longitude,Latitude]
#       .Path.CXLVIII     :Path   [Longitude,Latitude]
#       .Path.CXLIX       :Path   [Longitude,Latitude]
#       .Path.CL          :Path   [Longitude,Latitude]
#       .Path.CLI         :Path   [Longitude,Latitude]
#       .Path.CLII        :Path   [Longitude,Latitude]
#       .Path.CLIII       :Path   [Longitude,Latitude]
#       .Path.CLIV        :Path   [Longitude,Latitude]
#       .Path.CLV         :Path   [Longitude,Latitude]
#       .Path.CLVI        :Path   [Longitude,Latitude]
#       .Path.CLVII       :Path   [Longitude,Latitude]
#       .Path.CLVIII      :Path   [Longitude,Latitude]
#       .Path.CLIX        :Path   [Longitude,Latitude]
#       .Path.CLX         :Path   [Longitude,Latitude]
#       .Path.CLXI        :Path   [Longitude,Latitude]
#       .Path.CLXII       :Path   [Longitude,Latitude]
#       .Path.CLXIII      :Path   [Longitude,Latitude]
#       .Path.CLXIV       :Path   [Longitude,Latitude]
#       .Path.CLXV        :Path   [Longitude,Latitude]
#       .Path.CLXVI       :Path   [Longitude,Latitude]
#       .Path.CLXVII      :Path   [Longitude,Latitude]
#       .Path.CLXVIII     :Path   [Longitude,Latitude]
#       .Path.CLXIX       :Path   [Longitude,Latitude]
#       .Path.CLXX        :Path   [Longitude,Latitude]
#       .Path.CLXXI       :Path   [Longitude,Latitude]
#       .Path.CLXXII      :Path   [Longitude,Latitude]
#       .Path.CLXXIII     :Path   [Longitude,Latitude]
#       .Path.CLXXIV      :Path   [Longitude,Latitude]
#       .Path.CLXXV       :Path   [Longitude,Latitude]
#       .Path.CLXXVI      :Path   [Longitude,Latitude]
#       .Path.CLXXVII     :Path   [Longitude,Latitude]
#       .Path.CLXXVIII    :Path   [Longitude,Latitude]
#       .Path.CLXXIX      :Path   [Longitude,Latitude]
#       .Path.CLXXX       :Path   [Longitude,Latitude]
#       .Path.CLXXXI      :Path   [Longitude,Latitude]
#       .Path.CLXXXII     :Path   [Longitude,Latitude]
#       .Path.CLXXXIII    :Path   [Longitude,Latitude]
#       .Path.CLXXXIV     :Path   [Longitude,Latitude]
#       .Path.CLXXXV      :Path   [Longitude,Latitude]
#       .Path.CLXXXVI     :Path   [Longitude,Latitude]
#       .Path.CLXXXVII    :Path   [Longitude,Latitude]
#       .Path.CLXXXVIII   :Path   [Longitude,Latitude]
#       .Path.CLXXXIX     :Path   [Longitude,Latitude]
#       .Path.CXC         :Path   [Longitude,Latitude]
#       .Path.CXCI        :Path   [Longitude,Latitude]
#       .Path.CXCII       :Path   [Longitude,Latitude]
#       .Path.CXCIII      :Path   [Longitude,Latitude]
#       .Path.CXCIV       :Path   [Longitude,Latitude]
#       .Path.CXCV        :Path   [Longitude,Latitude]
#       .Path.CXCVI       :Path   [Longitude,Latitude]
#       .Path.CXCVII      :Path   [Longitude,Latitude]
#       .Path.CXCVIII     :Path   [Longitude,Latitude]
#       .Path.CXCIX       :Path   [Longitude,Latitude]
#       .Path.CC          :Path   [Longitude,Latitude]
#       .Path.CCI         :Path   [Longitude,Latitude]
#       .Path.CCII        :Path   [Longitude,Latitude]
#       .Path.CCIII       :Path   [Longitude,Latitude]
#       .Path.CCIV        :Path   [Longitude,Latitude]
#       .Path.CCV         :Path   [Longitude,Latitude]
#       .Path.CCVI        :Path   [Longitude,Latitude]
#       .Path.CCVII       :Path   [Longitude,Latitude]
#       .Path.CCVIII      :Path   [Longitude,Latitude]
#       .Path.CCIX        :Path   [Longitude,Latitude]
#       .Path.CCX         :Path   [Longitude,Latitude]
#       .Path.CCXI        :Path   [Longitude,Latitude]
#       .Path.CCXII       :Path   [Longitude,Latitude]
#       .Path.CCXIII      :Path   [Longitude,Latitude]
#       .Path.CCXIV       :Path   [Longitude,Latitude]
#       .Path.CCXV        :Path   [Longitude,Latitude]
#       .Path.CCXVI       :Path   [Longitude,Latitude]
#       .Path.CCXVII      :Path   [Longitude,Latitude]
#       .Path.CCXVIII     :Path   [Longitude,Latitude]
#       .Path.CCXIX       :Path   [Longitude,Latitude]
#       .Path.CCXX        :Path   [Longitude,Latitude]
#       .Path.CCXXI       :Path   [Longitude,Latitude]
#       .Path.CCXXII      :Path   [Longitude,Latitude]
#       .Points.I         :Points   [Longitude,Latitude]   (triangle_angle)
#       .Points.II        :Points   [Longitude,Latitude]   (triangle_angle)
#       .Points.III       :Points   [Longitude,Latitude]   (triangle_angle)
#       .Points.IV        :Points   [Longitude,Latitude]   (triangle_angle)
#       .Points.V         :Points   [Longitude,Latitude]   (triangle_angle)
#       .Points.VI        :Points   [Longitude,Latitude]   (triangle_angle)
#       .Points.VII       :Points   [Longitude,Latitude]   (triangle_angle)
#       .Points.VIII      :Points   [Longitude,Latitude]   (triangle_angle)
#       .Points.IX        :Points   [Longitude,Latitude]   (triangle_angle)
#       .Points.X         :Points   [Longitude,Latitude]   (triangle_angle)
#       .Points.XI        :Points   [Longitude,Latitude]   (triangle_angle)
#       .Points.XII       :Points   [Longitude,Latitude]   (triangle_angle)
#       .Points.XIII      :Points   [Longitude,Latitude]   (triangle_angle)
#       .Points.XIV       :Points   [Longitude,Latitude]   (triangle_angle)
#       .Points.XV        :Points   [Longitude,Latitude]   (triangle_angle)
#       .Points.XVI       :Points   [Longitude,Latitude]   (triangle_angle)
#       .Points.XVII      :Points   [Longitude,Latitude]   (triangle_angle)
#       .Points.XVIII     :Points   [Longitude,Latitude]   (triangle_angle)
#       .Points.XIX       :Points   [Longitude,Latitude]   (triangle_angle)
#       .Points.XX        :Points   [Longitude,Latitude]   (triangle_angle)
#       .Points.XXI       :Points   [Longitude,Latitude]   (triangle_angle)
#       .Points.XXII      :Points   [Longitude,Latitude]   (triangle_angle)
#       .Points.XXIII     :Points   [Longitude,Latitude]   (triangle_angle)
#       .Points.XXIV      :Points   [Longitude,Latitude]   (triangle_angle)
#       .Points.XXV       :Points   [Longitude,Latitude]   (triangle_angle)
#       .Points.XXVI      :Points   [Longitude,Latitude]   (triangle_angle)
#       .Points.XXVII     :Points   [Longitude,Latitude]   (triangle_angle)
#       .Points.XXVIII    :Points   [Longitude,Latitude]   (triangle_angle)
#       .Points.XXIX      :Points   [Longitude,Latitude]   (triangle_angle)
#       .Points.XXX       :Points   [Longitude,Latitude]   (triangle_angle)
#       .Points.XXXI      :Points   [Longitude,Latitude]   (triangle_angle)
#       .Points.XXXII     :Points   [Longitude,Latitude]   (triangle_angle)
#       .Points.XXXIII    :Points   [Longitude,Latitude]   (triangle_angle)
#       .Points.XXXIV     :Points   [Longitude,Latitude]   (triangle_angle)
#       .Points.XXXV      :Points   [Longitude,Latitude]   (triangle_angle)
#       .Points.XXXVI     :Points   [Longitude,Latitude]   (triangle_angle)
#       .Points.XXXVII    :Points   [Longitude,Latitude]   (triangle_angle)
#       .Points.XXXVIII   :Points   [Longitude,Latitude]   (triangle_angle)
#       .Points.XXXIX     :Points   [Longitude,Latitude]   (triangle_angle)
#       .Points.XL        :Points   [Longitude,Latitude]   (triangle_angle)
#       .Points.XLI       :Points   [Longitude,Latitude]   (triangle_angle)
#       .Points.XLII      :Points   [Longitude,Latitude]   (triangle_angle)
#       .Points.XLIII     :Points   [Longitude,Latitude]   (triangle_angle)
#       .Points.XLIV      :Points   [Longitude,Latitude]   (triangle_angle)
#       .Points.XLV       :Points   [Longitude,Latitude]   (triangle_angle)
#       .Points.XLVI      :Points   [Longitude,Latitude]   (triangle_angle)
#       .Points.XLVII     :Points   [Longitude,Latitude]   (triangle_angle)
#       .Points.XLVIII    :Points   [Longitude,Latitude]   (triangle_angle)
#       .Points.XLIX      :Points   [Longitude,Latitude]   (triangle_angle)
#       .Points.L         :Points   [Longitude,Latitude]   (triangle_angle)
#       .Points.LI        :Points   [Longitude,Latitude]   (triangle_angle)
#       .Points.LII       :Points   [Longitude,Latitude]   (triangle_angle)
#       .Points.LIII      :Points   [Longitude,Latitude]   (triangle_angle)
#       .Points.LIV       :Points   [Longitude,Latitude]   (triangle_angle)
#       .Points.LV        :Points   [Longitude,Latitude]   (triangle_angle)
#       .Points.LVI       :Points   [Longitude,Latitude]   (triangle_angle)
#       .Points.LVII      :Points   [Longitude,Latitude]   (triangle_angle)
#       .Points.LVIII     :Points   [Longitude,Latitude]   (triangle_angle)
#       .Points.LIX       :Points   [Longitude,Latitude]   (triangle_angle)
#       .Points.LX        :Points   [Longitude,Latitude]   (triangle_angle)
#       .Points.LXI       :Points   [Longitude,Latitude]   (triangle_angle)
#       .Points.LXII      :Points   [Longitude,Latitude]   (triangle_angle)
#       .Points.LXIII     :Points   [Longitude,Latitude]   (triangle_angle)
#       .Points.LXIV      :Points   [Longitude,Latitude]   (triangle_angle)
#       .Points.LXV       :Points   [Longitude,Latitude]   (triangle_angle)
#       .Points.LXVI      :Points   [Longitude,Latitude]   (triangle_angle)
#       .Points.LXVII     :Points   [Longitude,Latitude]   (triangle_angle)
#       .Points.LXVIII    :Points   [Longitude,Latitude]   (triangle_angle)
#       .Points.LXIX      :Points   [Longitude,Latitude]   (triangle_angle)
#       .Points.LXX       :Points   [Longitude,Latitude]   (triangle_angle)
#       .Points.LXXI      :Points   [Longitude,Latitude]   (triangle_angle)
#       .Points.LXXII     :Points   [Longitude,Latitude]   (triangle_angle)
#       .Points.LXXIII    :Points   [Longitude,Latitude]   (triangle_angle)
#       .Points.LXXIV     :Points   [Longitude,Latitude]   (triangle_angle)
#       .Points.LXXV      :Points   [Longitude,Latitude]   (triangle_angle)
#       .Points.LXXVI     :Points   [Longitude,Latitude]   (triangle_angle)
#       .Points.LXXVII    :Points   [Longitude,Latitude]   (triangle_angle)
#       .Points.LXXVIII   :Points   [Longitude,Latitude]   (triangle_angle)
#       .Points.LXXIX     :Points   [Longitude,Latitude]   (triangle_angle)
#       .Points.LXXX      :Points   [Longitude,Latitude]   (triangle_angle)
#       .Points.LXXXI     :Points   [Longitude,Latitude]   (triangle_angle)
#       .Points.LXXXII    :Points   [Longitude,Latitude]   (triangle_angle)
#       .Points.LXXXIII   :Points   [Longitude,Latitude]   (triangle_angle)
#       .Points.LXXXIV    :Points   [Longitude,Latitude]   (triangle_angle)
#       .Points.LXXXV     :Points   [Longitude,Latitude]   (triangle_angle)
#       .Points.LXXXVI    :Points   [Longitude,Latitude]   (triangle_angle)
#       .Points.LXXXVII   :Points   [Longitude,Latitude]   (triangle_angle)
#       .Points.LXXXVIII  :Points   [Longitude,Latitude]   (triangle_angle)
#       .Points.LXXXIX    :Points   [Longitude,Latitude]   (triangle_angle)
#       .Points.XC        :Points   [Longitude,Latitude]   (triangle_angle)
#       .Points.XCI       :Points   [Longitude,Latitude]   (triangle_angle)
#       .Points.XCII      :Points   [Longitude,Latitude]   (triangle_angle)
#       .Points.XCIII     :Points   [Longitude,Latitude]   (triangle_angle)
#       .Points.XCIV      :Points   [Longitude,Latitude]   (triangle_angle)
#       .Points.XCV       :Points   [Longitude,Latitude]   (triangle_angle)
#       .Points.XCVI      :Points   [Longitude,Latitude]   (triangle_angle)
#       .Points.XCVII     :Points   [Longitude,Latitude]   (triangle_angle)
#       .Points.XCVIII    :Points   [Longitude,Latitude]   (triangle_angle)
#       .Points.XCIX      :Points   [Longitude,Latitude]   (triangle_angle)
#       .Points.C         :Points   [Longitude,Latitude]   (triangle_angle)
#       .Points.CI        :Points   [Longitude,Latitude]   (triangle_angle)
#       .Points.CII       :Points   [Longitude,Latitude]   (triangle_angle)
#       .Points.CIII      :Points   [Longitude,Latitude]   (triangle_angle)
#       .Points.CIV       :Points   [Longitude,Latitude]   (triangle_angle)
#       .Points.CV        :Points   [Longitude,Latitude]   (triangle_angle)
#       .Points.CVI       :Points   [Longitude,Latitude]   (triangle_angle)
#       .Points.CVII      :Points   [Longitude,Latitude]   (triangle_angle)
#       .Points.CVIII     :Points   [Longitude,Latitude]   (triangle_angle)
#       .Points.CIX       :Points   [Longitude,Latitude]   (triangle_angle)
#       .Points.CX        :Points   [Longitude,Latitude]   (triangle_angle)
#       .Points.CXI       :Points   [Longitude,Latitude]   (triangle_angle)
#       .Points.CXII      :Points   [Longitude,Latitude]   (triangle_angle)
#       .Points.CXIII     :Points   [Longitude,Latitude]   (triangle_angle)
#       .Points.CXIV      :Points   [Longitude,Latitude]   (triangle_angle)
#       .Points.CXV       :Points   [Longitude,Latitude]   (triangle_angle)
#       .Points.CXVI      :Points   [Longitude,Latitude]   (triangle_angle)
#       .Points.CXVII     :Points   [Longitude,Latitude]   (triangle_angle)
#       .Points.CXVIII    :Points   [Longitude,Latitude]   (triangle_angle)
#       .Points.CXIX      :Points   [Longitude,Latitude]   (triangle_angle)
#       .Points.CXX       :Points   [Longitude,Latitude]   (triangle_angle)
#       .Points.CXXI      :Points   [Longitude,Latitude]   (triangle_angle)
#       .Points.CXXII     :Points   [Longitude,Latitude]   (triangle_angle)
#       .Points.CXXIII    :Points   [Longitude,Latitude]   (triangle_angle)
#       .Points.CXXIV     :Points   [Longitude,Latitude]   (triangle_angle)
#       .Points.CXXV      :Points   [Longitude,Latitude]   (triangle_angle)
#       .Points.CXXVI     :Points   [Longitude,Latitude]   (triangle_angle)
#       .Points.CXXVII    :Points   [Longitude,Latitude]   (triangle_angle)
#       .Points.CXXVIII   :Points   [Longitude,Latitude]   (triangle_angle)
#       .Points.CXXIX     :Points   [Longitude,Latitude]   (triangle_angle)
#       .Points.CXXX      :Points   [Longitude,Latitude]   (triangle_angle)
#       .Points.CXXXI     :Points   [Longitude,Latitude]   (triangle_angle)
#       .Points.CXXXII    :Points   [Longitude,Latitude]   (triangle_angle)
#       .Points.CXXXIII   :Points   [Longitude,Latitude]   (triangle_angle)
#       .Points.CXXXIV    :Points   [Longitude,Latitude]   (triangle_angle)
#       .Points.CXXXV     :Points   [Longitude,Latitude]   (triangle_angle)
#       .Points.CXXXVI    :Points   [Longitude,Latitude]   (triangle_angle)
#       .Points.CXXXVII   :Points   [Longitude,Latitude]   (triangle_angle)
#       .Points.CXXXVIII  :Points   [Longitude,Latitude]   (triangle_angle)
#       .Points.CXXXIX    :Points   [Longitude,Latitude]   (triangle_angle)
#       .Points.CXL       :Points   [Longitude,Latitude]   (triangle_angle)
#       .Points.CXLI      :Points   [Longitude,Latitude]   (triangle_angle)
#       .Points.CXLII     :Points   [Longitude,Latitude]   (triangle_angle)
#       .Points.CXLIII    :Points   [Longitude,Latitude]   (triangle_angle)
#       .Points.CXLIV     :Points   [Longitude,Latitude]   (triangle_angle)
#       .Points.CXLV      :Points   [Longitude,Latitude]   (triangle_angle)
#       .Points.CXLVI     :Points   [Longitude,Latitude]   (triangle_angle)
#       .Points.CXLVII    :Points   [Longitude,Latitude]   (triangle_angle)
#       .Points.CXLVIII   :Points   [Longitude,Latitude]   (triangle_angle)
#       .Points.CXLIX     :Points   [Longitude,Latitude]   (triangle_angle)
#       .Points.CL        :Points   [Longitude,Latitude]   (triangle_angle)
#       .Points.CLI       :Points   [Longitude,Latitude]   (triangle_angle)
#       .Points.CLII      :Points   [Longitude,Latitude]   (triangle_angle)
#       .Points.CLIII     :Points   [Longitude,Latitude]   (triangle_angle)
#       .Points.CLIV      :Points   [Longitude,Latitude]   (triangle_angle)
#       .Points.CLV       :Points   [Longitude,Latitude]   (triangle_angle)
#       .Points.CLVI      :Points   [Longitude,Latitude]   (triangle_angle)
#       .Points.CLVII     :Points   [Longitude,Latitude]   (triangle_angle)
#       .Points.CLVIII    :Points   [Longitude,Latitude]   (triangle_angle)
#       .Points.CLIX      :Points   [Longitude,Latitude]   (triangle_angle)
#       .Points.CLX       :Points   [Longitude,Latitude]   (triangle_angle)
#       .Points.CLXI      :Points   [Longitude,Latitude]   (triangle_angle)
#       .Points.CLXII     :Points   [Longitude,Latitude]   (triangle_angle)
#       .Points.CLXIII    :Points   [Longitude,Latitude]   (triangle_angle)
#       .Points.CLXIV     :Points   [Longitude,Latitude]   (triangle_angle)
#       .Points.CLXV      :Points   [Longitude,Latitude]   (triangle_angle)
#       .Points.CLXVI     :Points   [Longitude,Latitude]   (triangle_angle)
#       .Points.CLXVII    :Points   [Longitude,Latitude]   (triangle_angle)
#       .Points.CLXVIII   :Points   [Longitude,Latitude]   (triangle_angle)
#       .Points.CLXIX     :Points   [Longitude,Latitude]   (triangle_angle)
#       .Points.CLXX      :Points   [Longitude,Latitude]   (triangle_angle)
#       .Points.CLXXI     :Points   [Longitude,Latitude]   (triangle_angle)
#       .Points.CLXXII    :Points   [Longitude,Latitude]   (triangle_angle)
#       .Points.CLXXIII   :Points   [Longitude,Latitude]   (triangle_angle)
#       .Points.CLXXIV    :Points   [Longitude,Latitude]   (triangle_angle)
#       .Points.CLXXV     :Points   [Longitude,Latitude]   (triangle_angle)
#       .Points.CLXXVI    :Points   [Longitude,Latitude]   (triangle_angle)
#       .Points.CLXXVII   :Points   [Longitude,Latitude]   (triangle_angle)
#       .Points.CLXXVIII  :Points   [Longitude,Latitude]   (triangle_angle)
#       .Points.CLXXIX    :Points   [Longitude,Latitude]   (triangle_angle)
#       .Points.CLXXX     :Points   [Longitude,Latitude]   (triangle_angle)
#       .Points.CLXXXI    :Points   [Longitude,Latitude]   (triangle_angle)
#       .Points.CLXXXII   :Points   [Longitude,Latitude]   (triangle_angle)
#       .Points.CLXXXIII  :Points   [Longitude,Latitude]   (triangle_angle)
#       .Points.CLXXXIV   :Points   [Longitude,Latitude]   (triangle_angle)
#       .Points.CLXXXV    :Points   [Longitude,Latitude]   (triangle_angle)
#       .Points.CLXXXVI   :Points   [Longitude,Latitude]   (triangle_angle)
#       .Points.CLXXXVII  :Points   [Longitude,Latitude]   (triangle_angle)
#       .Points.CLXXXVIII :Points   [Longitude,Latitude]   (triangle_angle)
#       .Points.CLXXXIX   :Points   [Longitude,Latitude]   (triangle_angle)
#       .Points.CXC       :Points   [Longitude,Latitude]   (triangle_angle)
#       .Points.CXCI      :Points   [Longitude,Latitude]   (triangle_angle)
#       .Points.CXCII     :Points   [Longitude,Latitude]   (triangle_angle)
#       .Points.CXCIII    :Points   [Longitude,Latitude]   (triangle_angle)
#       .Points.CXCIV     :Points   [Longitude,Latitude]   (triangle_angle)
#       .Points.CXCV      :Points   [Longitude,Latitude]   (triangle_angle)
#       .Points.CXCVI     :Points   [Longitude,Latitude]   (triangle_angle)
#       .Points.CXCVII    :Points   [Longitude,Latitude]   (triangle_angle)
#       .Points.CXCVIII   :Points   [Longitude,Latitude]   (triangle_angle)
#       .Points.CXCIX     :Points   [Longitude,Latitude]   (triangle_angle)
#       .Points.CC        :Points   [Longitude,Latitude]   (triangle_angle)
#       .Points.CCI       :Points   [Longitude,Latitude]   (triangle_angle)
#       .Points.CCII      :Points   [Longitude,Latitude]   (triangle_angle)
#       .Points.CCIII     :Points   [Longitude,Latitude]   (triangle_angle)
#       .Points.CCIV      :Points   [Longitude,Latitude]   (triangle_angle)
#       .Points.CCV       :Points   [Longitude,Latitude]   (triangle_angle)
#       .Points.CCVI      :Points   [Longitude,Latitude]   (triangle_angle)
#       .Points.CCVII     :Points   [Longitude,Latitude]   (triangle_angle)
#       .Points.CCVIII    :Points   [Longitude,Latitude]   (triangle_angle)
#       .Points.CCIX      :Points   [Longitude,Latitude]   (triangle_angle)
#       .Points.CCX       :Points   [Longitude,Latitude]   (triangle_angle)
#       .Points.CCXI      :Points   [Longitude,Latitude]   (triangle_angle)
#       .Points.CCXII     :Points   [Longitude,Latitude]   (triangle_angle)
#       .Points.CCXIII    :Points   [Longitude,Latitude]   (triangle_angle)
#       .Points.CCXIV     :Points   [Longitude,Latitude]   (triangle_angle)
#       .Points.CCXV      :Points   [Longitude,Latitude]   (triangle_angle)
#       .Points.CCXVI     :Points   [Longitude,Latitude]   (triangle_angle)
#       .Points.CCXVII    :Points   [Longitude,Latitude]   (triangle_angle)
#       .Points.CCXVIII   :Points   [Longitude,Latitude]   (triangle_angle)
#       .Points.CCXIX     :Points   [Longitude,Latitude]   (triangle_angle)
#       .Points.CCXX      :Points   [Longitude,Latitude]   (triangle_angle)
#       .Points.CCXXI     :Points   [Longitude,Latitude]   (triangle_angle)
#       .Points.CCXXII    :Points   [Longitude,Latitude]   (triangle_angle)
#    .Overlay.II  :Overlay
#       .WMTS.I   :WMTS   [Longitude,Latitude]
#       .Points.I :Points   [Longitude,Latitude]
#    .Overlay.III :Overlay
#       .WMTS.I   :WMTS   [Longitude,Latitude]
#       .Path.I   :Path   [Longitude,Latitude]
#       .Points.I :Points   [Longitude,Latitude]   (triangle_angle)

# %%
stops
# Out:
# TrajectoryCollection with 222 trajectories

# %%
time_stops = detector.get_stop_time_ranges(min_duration=datetime.timedelta(seconds=15), max_diameter=10)

# %%
median_pace = np.median(trajectory.get_length() / trajectory.get_duration().total_seconds())
median_pace_kmph = median_pace * 3.6
print(f"the median pace is {median_pace_kmph:.2f} km/h")
print(f"the median pace is {median_pace:.2f} m/s")
# Out:
# the median pace is 4.44 km/h
# the median pace is 1.23 m/s

# %%
trajectory.to_point_gdf().head()
# Out:
#                      track_id  traj_id                  geometry  \
# t
# 2023-08-19 10:08:43         1  traj_id  POINT (4.73950 52.64884)
# 2023-08-19 10:08:44         1  traj_id  POINT (4.73953 52.64880)
# 2023-08-19 10:08:45         1  traj_id  POINT (4.73953 52.64879)
# 2023-08-19 10:08:46         1  traj_id  POINT (4.73954 52.64880)
# 2023-08-19 10:08:47         1  traj_id  POINT (4.73955 52.64881)
#
#                      acceleration     speed       timedelta
# t
# 2023-08-19 10:08:43      0.000000  4.451457             NaT
# 2023-08-19 10:08:44      0.000000  4.451457 0 days 00:00:01
# 2023-08-19 10:08:45     -3.547671  0.903786 0 days 00:00:01
# 2023-08-19 10:08:46      0.138177  1.041962 0 days 00:00:01
# 2023-08-19 10:08:47      0.130245  1.172208 0 days 00:00:01

# %%
trajectory.to_point_gdf().to_file('../scratch/trajectory_points.geojson', driver='GeoJSON')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 trajectory.to_point_gdf().to_file('../scratch/trajectory_points.geojson', driver='GeoJSON')
#
# File ~\AppData\Roaming\Python\Python311\site-packages\geopandas\geodataframe.py:1246, in GeoDataFrame.to_file(self, filename, driver, schema, index, **kwargs)
#    1155 """Write the ``GeoDataFrame`` to a file.
#    1156
#    1157 By default, an ESRI shapefile is written, but any OGR data source
#    (...)
#    1242
#    1243 """
#    1244 from geopandas.io.file import _to_file
# -> 1246 _to_file(self, filename, driver, schema, index, **kwargs)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\geopandas\io\file.py:633, in _to_file(df, filename, driver, schema, index, mode, crs, engine, **kwargs)
#     630     raise ValueError(f"'mode' should be one of 'w' or 'a', got '{mode}' instead")
#     632 if engine == "fiona":
# --> 633     _to_file_fiona(df, filename, driver, schema, crs, mode, **kwargs)
#     634 elif engine == "pyogrio":
#     635     _to_file_pyogrio(df, filename, driver, schema, crs, mode, **kwargs)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\geopandas\io\file.py:664, in _to_file_fiona(df, filename, driver, schema, crs, mode, **kwargs)
#     660     crs_wkt = crs.to_wkt("WKT1_GDAL")
#     661 with fiona.open(
#     662     filename, mode=mode, driver=driver, crs_wkt=crs_wkt, schema=schema, **kwargs
#     663 ) as colxn:
# --> 664     colxn.writerecords(df.iterfeatures())
#
# File ~\AppData\Roaming\Python\Python311\site-packages\fiona\collection.py:558, in Collection.writerecords(self, records)
#     556 if self.mode not in ("a", "w"):
#     557     raise OSError("collection not open for writing")
# --> 558 self.session.writerecs(records, self)
#     559 self._len = self.session.get_length()
#     560 self._bounds = None
#
# File fiona\\ogrext.pyx:1409, in fiona.ogrext.WritingSession.writerecs()
#
# File fiona\\ogrext.pyx:514, in fiona.ogrext.OGRFeatureBuilder.build()
#
# ValueError: Invalid field type <class 'pandas._libs.tslibs.timedeltas.Timedelta'>

# %% [markdown]
# #### 6. Conclusion
